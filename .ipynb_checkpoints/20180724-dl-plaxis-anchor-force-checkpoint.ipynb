# %% [markdown]
# # Automate generating of the HoopForce using Python

# %%
#load in the path to the Plaxis 
import imp
import plaxisremote as plxrmt
from plaxisremote import output
import plaxisremote as plx
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from PIL import Image
from IPython.display import Image
# %matplotlib inline

# %%
port_o = 10001
port_I = 10000
plx_o = output(port_o)
path = r'\\HKGNTS22\geo\Actual Job\211036\11-00 Calculations\11-02 Seawall Design\Post 2016 GI\02 Sections\CH 3850 P_C2b C092\01 Plaxis\UD Study'
os.chdir(path)
g_o = plx_o.g_o
# plx_o.open_file(os.path.join(path,'CH4150_C099_Udr_Rev01.p2dx'))
#plx_o.open_file(r'C:\Users\dazhong.li\Desktop\New folder (4)\MCC_AxSC_UPMW_r02.p2dx')

# %%
# df = plx_o.get_anchor_force('Phase_3')
# df_hoop_force_prior_FOS= plxrmt.find_hoop_force(df,'yb')
# df = plx_o.get_anchor_force('Phase_6')
# df_hoop_force_FOS = plxrmt.find_hoop_force(df,'yb')
#----Landscape case
df = plx_o.get_anchor_force('Phase_25')
df_hoop_force_prior_FOS= plxrmt.find_hoop_force(df,'yb')
df = plx_o.get_anchor_force('Phase_26')
df_hoop_force_FOS = plxrmt.find_hoop_force(df,'yb')

# %% [markdown]
# ## Setup a paper for plot

# %%
# title = 'Hoop Foce at C092 for Baseline Undrained Case'
title = 'Hoop Foce at C092 for Landscape Undrained Case'
fig = plt.figure(figsize=(8.27,11.69))
ax = fig.add_subplot(111)
ax.plot([2000,2000],[5,-30],label= 'Allowable web tension capacity with FOS of 1.4, corrosion to 8mm',linestyle='-.')
ax.plot([2840,2840],[5,-30],label= 'Ultimate web tension capacity, corrosion to 8mm',linestyle='-.')
ax.plot([3200,3200],[5,-30],label= 'Allowable web tension capacity with FOS of 1.4, w/o corrosion',linestyle='-.')
ax.plot([4500,4500],[5,-30],label= 'Ultimate web tension capacity, w/o corrosion',linestyle='-.')
df_hoop_force_prior_FOS.plot(x='force',y='y',ax=ax,label='SEAWARD WALL (Prior to FOS Stage)',c='b',marker='*')
df_hoop_force_FOS.plot(x='force',y='y',ax=ax,label='SEAWARD WALL (FOS Stage)',c='r',marker='^')
ax.legend(loc=4)
ax.set_ylabel('Elevation(mPD)')
ax.set_xlabel('Force (kN)')
ax.set_xlim(0,5000)
ax.set_ylim(-35,-0)
ax.grid()
fig.suptitle(title)
fig.tight_layout()
fig.savefig(title + '.pdf')

# %%
x = g_o.Plots[0].export(800,600)

# %%
result_image  = Image.new(x.mode,x.size)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-33-a0e448c4a3b5> in <module>()
# ----> 1 result_image  = Image.new(x.mode,x.size)
#
# AttributeError: 'PILImageWrapper' object has no attribute 'mode'

# %%
x.save('test.png')

# %%
g_o.Plots[0].Phase = g_o.Phase_24

# %%
x = g_o.Plots[0].export(800,600)

# %%
g_o.Plots[0].setproperties('ScaleFactor',0)
g_o.Plots[0].setproperties('ResultType', g_o.ResultType.Soil.Uy)
g_o.Plots[0].Phase = g_o.Phase_23
x = g_o.Plots[0].export(800,600)
x.save('test.png')
Image('test.png')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-59-392a27cb0d40> in <module>()
#       1 g_o.Plots[0].setproperties('ScaleFactor',0)
# ----> 2 g_o.Plots[0].setproperties('ResultType', g_o.ResultType.Soil.Uy)
#       3 g_o.Plots[0].Phase = g_o.Phase_23
#       4 x = g_o.Plots[0].export(800,600)
#       5 x.save('test.png')
#
# C:\Program Files\Plaxis\PLAXIS 2D\plxscripting\plxproxy.py in __getattr__(self, attr_name)
#     100
#     101         raise AttributeError(
# --> 102             "Requested attribute '{}' is not present".format(attr_name))
#     103
#     104     def _ensure_cache_is_valid(self):
#
# AttributeError: Requested attribute 'ResultType' is not present

# %%
Image('test.png')

# %%
x= g_o.Plots[0]

# %%
x.setproperties('ScaleFactor',50)
# Out:
# 'OK'
