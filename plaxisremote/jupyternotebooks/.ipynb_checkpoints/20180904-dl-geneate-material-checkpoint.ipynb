# %%
import os
import plaxisremote.plaxisremote as plx

# %%
output_port = 1000

# %%
plx_out = plx.Output(output_port)

# %%
g_o = plx_out.g_o

# %%
g_o.Phases
# Out:
# ---------------------------------------------------------------------------
# ConnectionRefusedError                    Traceback (most recent call last)
# C:\Program Files\Plaxis\PLAXIS 2D\plxscripting\requests\packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, **response_kw)
#     479                                                   timeout=timeout,
# --> 480                                                   body=body, headers=headers)
#     481
#
# C:\Program Files\Plaxis\PLAXIS 2D\plxscripting\requests\packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, **httplib_request_kw)
#     284             # urllib3.request. It also calls makefile (recv) on the socket.
# --> 285             conn.request(method, url, **httplib_request_kw)
#     286         except SocketTimeout:
#
# ...
